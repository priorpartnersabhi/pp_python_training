# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#Load csv
imd_df = pd.read_csv(r"C:\Users\abhimanya.achara\Downloads\File_7_-_All_IoD2019_Scores__Ranks__Deciles_and_Population_Denominators_3(3).csv")
#print first 5 rows 
imd_df.head()
# Out:
#     LSOA11cd                 LSOA11name    lad19cd               lad19nm  \
# 0  E01000001        City of London 001A  E09000001        City of London
# 1  E01000002        City of London 001B  E09000001        City of London
# 2  E01000003        City of London 001C  E09000001        City of London
# 3  E01000005        City of London 001E  E09000001        City of London
# 4  E01000006  Barking and Dagenham 016A  E09000002  Barking and Dagenham
#
#    Index_of_Multiple_Deprivation_IMD_Score  \
# 0                                    6.208
# 1                                    5.143
# 2                                   19.402
# 3                                   28.652
# 4                                   19.837
#
#    Index_of_Multiple_Deprivation_IMD_Rank  \
# 0                                   29199
# 1                                   30379
# 2                                   14915
# 3                                    8678
# 4                                   14486
#
# ...

# %%
#print last 5 rows
imd_df.tail()
# Out:
#         LSOA11cd      LSOA11name    lad19cd    lad19nm  \
# 32839  E01033764  Liverpool 022E  E08000012  Liverpool
# 32840  E01033765  Liverpool 061D  E08000012  Liverpool
# 32841  E01033766  Liverpool 042G  E08000012  Liverpool
# 32842  E01033767  Liverpool 050J  E08000012  Liverpool
# 32843  E01033768  Liverpool 037F  E08000012  Liverpool
#
#        Index_of_Multiple_Deprivation_IMD_Score  \
# 32839                                   74.468
# 32840                                   59.599
# 32841                                   21.895
# 32842                                   66.704
# 32843                                   52.286
#
#        Index_of_Multiple_Deprivation_IMD_Rank  \
# 32839                                     116
# 32840                                     945
# 32841                                   12842
# 32842                                     422
# 32843                                    1833
#
# ...

# %%
#describe the dataset
imd_df.describe()
# Out:
#        Index_of_Multiple_Deprivation_IMD_Score  \
# count                             32844.000000
# mean                                 21.669393
# std                                  15.332229
# min                                   0.541000
# 25%                                   9.913750
# 50%                                  17.647500
# 75%                                  29.583000
# max                                  92.735000
#
#        Index_of_Multiple_Deprivation_IMD_Rank  \
# count                            32844.000000
# mean                             16422.499208
# std                               9481.390454
# min                                  1.000000
# 25%                               8211.750000
# 50%                              16422.500000
# 75%                              24633.250000
# max                              32844.000000
#
#        Index_of_Multiple_Deprivation_IMD_Decile  Income_Score_rate  \
# ...

# %%
#get details on the columsn of 
imd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32844 entries, 0 to 32843
# Data columns (total 57 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   LSOA11cd                                                                                        32844 non-null  object
#  1   LSOA11name                                                                                      32844 non-null  object
#  2   lad19cd                                                                                         32844 non-null  object
#  3   lad19nm                                                                                         32844 non-null  object
#  4   Index_of_Multiple_Deprivation_IMD_Score                                                         32844 non-null  float64
# ...

# %%
imd_df.drop(['Index_of_Multiple_Deprivation_IMD_Score', 'Index_of_Multiple_Deprivation_IMD_Rank', 'Income_Score_rate', 'Income_Rank', 'Employment_Score_rate','Employment_Rank'],1,inplace = True)
# Out:
# C:\Users\abhimanya.achara\AppData\Local\Temp\ipykernel_32796\4196661714.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   imd_df.drop(['Index_of_Multiple_Deprivation_IMD_Score', 'Index_of_Multiple_Deprivation_IMD_Rank', 'Income_Score_rate', 'Income_Rank', 'Employment_Score_rate','Employment_Rank'],1,inplace = True)

# %%
imd_df.head()
# Out:
#     LSOA11cd                 LSOA11name    lad19cd               lad19nm  \
# 0  E01000001        City of London 001A  E09000001        City of London
# 1  E01000002        City of London 001B  E09000001        City of London
# 2  E01000003        City of London 001C  E09000001        City of London
# 3  E01000005        City of London 001E  E09000001        City of London
# 4  E01000006  Barking and Dagenham 016A  E09000002  Barking and Dagenham
#
#    Index_of_Multiple_Deprivation_IMD_Decile  Income_Decile  Employment_Decile  \
# 0                                         9             10                 10
# 1                                        10             10                 10
# 2                                         5              6                  5
# 3                                         3              2                  3
# 4                                         5              5                  7
#
# ...

# %%
rename_columns = {'LSOA11cd':'lsoa11cd', 'LSOA11name':'lsoa11nm'}
imd_df.rename(columns = rename_columns, inplace = True)
imd_df.head()
# Out:
#     lsoa11cd                   lsoa11nm    lad19cd               lad19nm  \
# 0  E01000001        City of London 001A  E09000001        City of London
# 1  E01000002        City of London 001B  E09000001        City of London
# 2  E01000003        City of London 001C  E09000001        City of London
# 3  E01000005        City of London 001E  E09000001        City of London
# 4  E01000006  Barking and Dagenham 016A  E09000002  Barking and Dagenham
#
#    Index_of_Multiple_Deprivation_IMD_Decile  Income_Decile  Employment_Decile  \
# 0                                         9             10                 10
# 1                                        10             10                 10
# 2                                         5              6                  5
# 3                                         3              2                  3
# 4                                         5              5                  7
#
# ...

# %%
#Load csv
rename_df = pd.read_csv(r"C:\Users\abhimanya.achara\Downloads\rename_sample.csv")
#print first 5 rows 
rename_df.head()
# Out:
#                                    lsoa11cd  new name 01
# 0                                  lsoa11nm  new name 02
# 1                                   lad19cd  new name 03
# 2                                   lad19nm  new name 04
# 3  Index_of_Multiple_Deprivation_IMD_Decile  new name 05
# 4                             Income_Decile  new name 06

# %%
rename_dict = {}
for i, j in zip(rename_df['lsoa11cd'].values, rename_df['new name 01'].values):
    rename_dict[i] = j

# %%
print(rename_dict)
# Out:
# {'lsoa11nm': 'new name 02', 'lad19cd': 'new name 03', 'lad19nm': 'new name 04', 'Index_of_Multiple_Deprivation_IMD_Decile': 'new name 05', 'Income_Decile': 'new name 06', 'Employment_Decile': 'new name 07', 'Education,_Skills_and_Training_Score': 'new name 08', 'Education,_Skills_and_Training_Rank': 'new name 09', 'Education,_Skills_and_Training_Decile': 'new name 10', '...': 'new name 11', 'Indoors_Subdomain_Rank': 'new name 12', 'Indoors_Subdomain_Decile': 'new name 13', 'Outdoors_Subdomain_Score': 'new name 14', 'Outdoors_Subdomain_Rank': 'new name 15', 'Outdoors_Subdomain_Decile': 'new name 16', 'Total_population_mid_2015_excluding_prisoners': 'new name 17', 'Dependent_Children_aged_015_mid_2015_excluding_prisoners': 'new name 18', 'Population_aged_1659_mid_2015_excluding_prisoners': 'new name 19', 'Older_population_aged_60_and_over_mid_2015_excluding_prisoners': 'new name 20', 'Working_age_population_18_59_64_for_use_with_Employment_Deprivation_Domain_excluding_prisoners': 'new 
# ...

# %%
imd_df.rename(columns = rename_dict, inplace = True)
imd_df.head()
# Out:
#     lsoa11cd                new name 02 new name 03           new name 04  \
# 0  E01000001        City of London 001A   E09000001        City of London
# 1  E01000002        City of London 001B   E09000001        City of London
# 2  E01000003        City of London 001C   E09000001        City of London
# 3  E01000005        City of London 001E   E09000001        City of London
# 4  E01000006  Barking and Dagenham 016A   E09000002  Barking and Dagenham
#
#    new name 05  new name 06  new name 07  new name 08  new name 09  \
# 0            9           10           10        0.024        32842
# 1           10           10           10        0.063        32832
# 2            5            6            5        5.804        26386
# 3            3            2            3       22.260        12370
# 4            5            5            7       14.798        17511
#
#    new name 10  ...  new name 12  new name 13  new name 14  new name 15  \
# ...

# %%
filtered_df = imd_df.loc[(imd_df['new name 04'] == 'Haringey') & (imd_df['new name 05']<=3)]
filtered_df.head(50)
# Out:
#        lsoa11cd    new name 02 new name 03 new name 04  new name 05  \
# 1921  E01001969  Haringey 001A   E09000014    Haringey            3
# 1922  E01001970  Haringey 004B   E09000014    Haringey            3
# 1923  E01001971  Haringey 001B   E09000014    Haringey            2
# 1928  E01001976  Haringey 011A   E09000014    Haringey            2
# 1929  E01001977  Haringey 011B   E09000014    Haringey            2
# 1930  E01001978  Haringey 011C   E09000014    Haringey            2
# 1931  E01001979  Haringey 011D   E09000014    Haringey            2
# 1932  E01001980  Haringey 018A   E09000014    Haringey            3
# 1933  E01001981  Haringey 018B   E09000014    Haringey            3
# 1934  E01001982  Haringey 018C   E09000014    Haringey            3
# 1935  E01001983  Haringey 018D   E09000014    Haringey            3
# 1951  E01001999  Haringey 023B   E09000014    Haringey            3
# 1954  E01002002  Haringey 031C   E09000014    Haringey            2
# ...

# %%
filtered_df['Deprivation_status'] = '30% most deprived in England'
filtered_df.head()
# Out:
# C:\Users\abhimanya.achara\AppData\Local\Temp\ipykernel_32796\2365608847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Deprivation_status'] = '30% most deprived in England'
#        lsoa11cd    new name 02 new name 03 new name 04  new name 05  \
# 1921  E01001969  Haringey 001A   E09000014    Haringey            3
# 1922  E01001970  Haringey 004B   E09000014    Haringey            3
# 1923  E01001971  Haringey 001B   E09000014    Haringey            2
# 1928  E01001976  Haringey 011A   E09000014    Haringey            2
# 1929  E01001977  Haringey 011B   E09000014    Haringey            2
#
#       new name 06  new name 07  new name 08  new name 09  new name 10  ...  \
# ...

# %%
imd_df['Deprivation_status_02'] = 'NA'
imd_df.loc[(imd_df['new name 04'] == 'Haringey') & (imd_df['new name 05']<=3), "Deprivation_status_02"] = '30% most deprived in England'
imd_df.head()
# Out:
#     lsoa11cd                new name 02 new name 03           new name 04  \
# 0  E01000001        City of London 001A   E09000001        City of London
# 1  E01000002        City of London 001B   E09000001        City of London
# 2  E01000003        City of London 001C   E09000001        City of London
# 3  E01000005        City of London 001E   E09000001        City of London
# 4  E01000006  Barking and Dagenham 016A   E09000002  Barking and Dagenham
#
#    new name 05  new name 06  new name 07  new name 08  new name 09  \
# 0            9           10           10        0.024        32842
# 1           10           10           10        0.063        32832
# 2            5            6            5        5.804        26386
# 3            3            2            3       22.260        12370
# 4            5            5            7       14.798        17511
#
#    new name 10  ...  new name 13  new name 14  new name 15  new name 16  \
# ...

# %%
imd_df.loc[(imd_df['new name 04'] == 'Haringey') & (imd_df['new name 05']<=3)]
# Out:
#         lsoa11cd    new name 02 new name 03 new name 04  new name 05  \
# 1921   E01001969  Haringey 001A   E09000014    Haringey            3
# 1922   E01001970  Haringey 004B   E09000014    Haringey            3
# 1923   E01001971  Haringey 001B   E09000014    Haringey            2
# 1928   E01001976  Haringey 011A   E09000014    Haringey            2
# 1929   E01001977  Haringey 011B   E09000014    Haringey            2
# ...          ...            ...         ...         ...          ...
# 2052   E01002102  Haringey 007C   E09000014    Haringey            3
# 2055   E01002105  Haringey 007D   E09000014    Haringey            3
# 31761  E01032575  Haringey 037D   E09000014    Haringey            2
# 32235  E01033085  Haringey 020E   E09000014    Haringey            3
# 32236  E01033086  Haringey 020F   E09000014    Haringey            2
#
#        new name 06  new name 07  new name 08  new name 09  new name 10  ...  \
# ...

# %%
plt.figure(figsize=(10, 10))
plt.bar(filtered_df['lsoa11cd'], filtered_df['new name 05'], width=0.8)

# Rotate x-axis labels
plt.xticks(rotation=90)

# Add axis labels
plt.xlabel("LSOA Code")
plt.ylabel("New Name 05 Value")

plt.title("Bar Chart of LSOA Codes vs. New Name 05")

plt.savefig("bar_chart.png", dpi=300, bbox_inches="tight")  # Saves as a high-quality PNG

plt.show()
